# %% [markdown]
# <a href="https://colab.research.google.com/github/Saranya003/TASK2/blob/main/Students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pymongo import MongoClient

# %%
saran=MongoClient("mongodb://Saranya:Sathish@ac-txvmzm7-shard-00-00.hv3nalw.mongodb.net:27017,ac-txvmzm7-shard-00-01.hv3nalw.mongodb.net:27017,ac-txvmzm7-shard-00-02.hv3nalw.mongodb.net:27017/?ssl=true&replicaSet=atlas-34tuc0-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
data=saran["StudentDatabase"]

# %%
A=data["Student_details"]

# %%
#load the student.json dataset.
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a2135bc2-4a11-43f5-a537-dd4f1b23281c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2135bc2-4a11-43f5-a537-dd4f1b23281c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_json("/content/students.json",lines=True)
df
# Out:
#      _id              name                                             scores
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# [200 rows x 3 columns]

# %%
DF_DICT=df.to_dict("records")
DF_DICT
# Out:
# [{'_id': 0,
#   'name': 'aimee Zank',
#   'scores': [{'score': 1.463179736705023, 'type': 'exam'},
#    {'score': 11.78273309957772, 'type': 'quiz'},
#    {'score': 35.8740349954354, 'type': 'homework'}]},
#  {'_id': 1,
#   'name': 'Aurelia Menendez',
#   'scores': [{'score': 60.06045071030959, 'type': 'exam'},
#    {'score': 52.79790691903873, 'type': 'quiz'},
#    {'score': 71.76133439165544, 'type': 'homework'}]},
#  {'_id': 2,
#   'name': 'Corliss Zuk',
#   'scores': [{'score': 67.03077096065002, 'type': 'exam'},
#    {'score': 6.301851677835235, 'type': 'quiz'},
#    {'score': 66.28344683278382, 'type': 'homework'}]},
#  {'_id': 3,
#   'name': 'Bao Ziglar',
#   'scores': [{'score': 71.64343899778332, 'type': 'exam'},
#    {'score': 24.80221293650313, 'type': 'quiz'},
#    {'score': 42.26147058804812, 'type': 'homework'}]},
#  {'_id': 4,
#   'name': 'Zachary Langlais',
#   'scores': [{'score': 78.68385091304332, 'type': 'exam'},
#    {'score': 90.2963101368042, 'type': 'quiz'},
# ...

# %%
#Insert the students record into the collection.
A.insert_many(DF_DICT)

# %% [markdown]
# ## 1)Find the student name who scored maximum scores in all (exam, quiz and homework)?

# %%
L=[]
for i in A.find({}):
    exam=i["scores"][0]["score"]
    quiz=i["scores"][1]["score"]
    homework=i["scores"][2]["score"]
    Total=exam+quiz+homework   
    i['total']=Total
    L.append(i)
max=pd.DataFrame(L)
print("Student name who scored max in all types:",max['name'].iloc[max["total"].idxmax()])
# Out:
# Student name who scored max in all types: Jessika Dagenais

# %% [markdown]
# # 2)Find students who scored below average in the exam and pass mark is 40%?

# %%
L=[]
for i in A.find({'scores.0.score':{'$gt':40,'$lte':65}},{'_id':0,'name':1}):
     
     L.append(i)

pd.DataFrame(L)
# Out:
#                  name
# 0    Aurelia Menendez
# 1      Wilburn Spiess
# 2        Denisha Cast
# 3      Quincy Danaher
# 4    Verdell Sowinski
# 5        Gisela Levin
# 6      Tressa Schwing
# 7        Rosana Vales
# 8    Tamika Schildgen
# 9     Gwyneth Garling
# 10       Kayce Kenyon
# 11     Terica Brugger
# 12          Chad Rahe
# 13        Grady Zemke
# 14     Vina Matsunaga
# 15    Jenise Mcguffie
# 16       Adrien Renda
# 17        Efrain Claw
# 18     Mariela Sherer
# 19         Rae Kohout
# 20         Cassi Heal
# 21   Demarcus Audette
# 22   Mercedez Garduno
# 23     Shin Allbright
# 24  Mikaela Meidinger
# 25        Flora Duell
# 26      Gennie Ratner
# 27   Zachary Langlais
# 28     Wilburn Spiess
# 29       Daphne Zheng
# 30       Marcus Blohm
# 31     Quincy Danaher
# 32      Alix Sherrill
# 33     Tambra Mercure
# 34      Dodie Staller
# 35     Tressa Schwing
# 36   Laureen Salomone
# 37    Gwyneth Garling
# 38   Richelle Siemers
# 39      Aleida Elsass
# ...

# %%
# 3)Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.

# %%
L1=[]
for i in A.find({'$and':[{'scores.0.score':{'$lte':40}},{'scores.1.score':{'$lte':40}},{'scores.2.score':{'$lte':40}}]}):
    i["Result"]="Fail"
    L.append(i)
fail=pd.DataFrame(L)

# %%
L2=[]
for i in A.find({'$and':[{'scores.0.score':{'$gt':40}},{'scores.1.score':{'$gt':40}},{'scores.2.score':{'$gt':40}}]}):
    i["Result"]="pass"
    L2.append(i)
p=pd.DataFrame(L2)

# %%
Result = [p,fail]
result=pd.concat(Result)
result
# Out:
#      _id              name                                             scores  \
# 0    1.0  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 1    7.0      Salena Olmos  [{'score': 90.37826509157176, 'type': 'exam'},...
# 2   10.0      Denisha Cast  [{'score': 45.61876862259409, 'type': 'exam'},...
# 3   11.0      Marcus Blohm  [{'score': 78.42617835651868, 'type': 'exam'},...
# 4   12.0    Quincy Danaher  [{'score': 54.29841278520669, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 49   NaN    Mariela Sherer                                                NaN
# 50   NaN     Linnie Weigel                                                NaN
# 51   NaN  Santiago Dollins                                                NaN
# 52   0.0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 53   0.0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
#
#    Result
# 0    pass
# ...

# %%
# 4)Find the total and average of the exam, quiz and homework and store them in a separate collection.

# %%
List=[]
for i in A.find({}):
    dic={}
    exam=i["scores"][0]["score"]
    quiz=i["scores"][1]["score"]
    homework=i["scores"][2]["score"]
    total=exam+quiz+homework
    a=total/3
    dic["id"]=i['_id']
    dic["Name"]=i["name"]
    dic["Total"]=total
    dic["Avgerage"]=a
    List.append(dic)

DF=pd.DataFrame(List)
DF1=DF.to_dict("records")
DF1
# Out:
# [{'id': 0,
#   'Name': 'aimee Zank',
#   'Total': 49.11994783171814,
#   'Avgerage': 16.373315943906046},
#  {'id': 1,
#   'Name': 'Aurelia Menendez',
#   'Total': 184.61969202100374,
#   'Avgerage': 61.53989734033458},
#  {'id': 2,
#   'Name': 'Corliss Zuk',
#   'Total': 139.61606947126907,
#   'Avgerage': 46.53868982375636},
#  {'id': 3,
#   'Name': 'Bao Ziglar',
#   'Total': 138.70712252233457,
#   'Avgerage': 46.23570750744486},
#  {'id': 4,
#   'Name': 'Zachary Langlais',
#   'Total': 203.3963625302728,
#   'Avgerage': 67.79878751009093},
#  {'id': 5,
#   'Name': 'Wilburn Spiess',
#   'Total': 134.0186975547794,
#   'Avgerage': 44.67289918492647},
#  {'id': 6,
#   'Name': 'Jenette Flanders',
#   'Total': 147.2203575476617,
#   'Avgerage': 49.07345251588723},
#  {'id': 7,
#   'Name': 'Salena Olmos',
#   'Total': 229.3959334774732,
#   'Avgerage': 76.46531115915774},
#  {'id': 8,
#   'Name': 'Daphne Zheng',
#   'Total': 112.71677331754347,
#   'Avgerage': 37.57225777251449},
# ...

# %%
B=data["Average"]
B.insert_many(DF1)

# %%
# 5)Create a new collection which consists of students who scored below average and above 40% in all the categories.

# %%
List1=[]
for i in A.find({'$and':[{'scores.0.score':{'$gt':40,'$lte':70}},{'scores.1.score':{'$gt':40,'$lte':70}},{'scores.2.score':{'$gt':40,'$lte':70}}]}):
    List1.append(i)
DF2=pd.DataFrame(List1)
belowAverage=DF2.to_dict("records")

# %%
C=data["Below_Average"]
C.insert_many(belowAverage)

# %%
 # 6)Create a new collection which consists of students who scored below the fail mark in all the categories.

# %%
List2=[]
for i in A.find({'$and':[{'scores.0.score':{'$lte':40}},{'scores.1.score':{'$lte':40}},{'scores.2.score':{'$lte':40}}]}):   
    List2.append(i)
DF3=pd.DataFrame(List2)
fail=DF3.to_dict("records")

# %%
D=data["Falied"]
D.insert_many(fail)

# %%
# 7)Create a new collection which consists of students who scored above pass mark in all the categories.

# %%
List3=[]
for i in A.find({'$and':[{'scores.0.score':{'$gt':40}},{'scores.1.score':{'$gt':40}},{'scores.2.score':{'$gt':40}}]}):
   List3.append(i)
DF4=pd.DataFrame(List3)
P=DF4.to_dict("records")

# %%
E=data["passed"]
E.insert_many(P)

# %% [markdown]
# #                    **Telephone Directory CRUD Operation**

# %%
#Import necessary modules

from pymongo import MongoClient
import pandas as pd

# %%
saran=MongoClient("mongodb://Saranya:Sathish@ac-txvmzm7-shard-00-00.hv3nalw.mongodb.net:27017,ac-txvmzm7-shard-00-01.hv3nalw.mongodb.net:27017,ac-txvmzm7-shard-00-02.hv3nalw.mongodb.net:27017/?ssl=true&replicaSet=atlas-34tuc0-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
#Create a database

db=saran["Client"]

# %%
#Create a collection.
A=db["telephoneDirectory"]

# %%
#insert data to collection 

Data=[{"id":0,"Name":"saran","Country code":"+91","Mobile No.":9159623987,"Address":"2/129 Vellore,TamilNadu,India."},
      {"id":1,"Name":"sathish","Country code":"+91","Mobile No.":74869368593,"Address":"2-33,tiruattur,TN,India."},
      {"id":2,"Name":"logu","Country code":"+91","Mobile No.":8455765655,"Address":"55-6,anna road,Chennai,India."},
      {"id":3,"Name":"dharuman","Country code":"+91","Mobile No.":6495639952,"Address":"1/85,Anna salai,trichy,India."},
      {"id":4,"Name":"nivetha","Country code":"+91","Mobile No.":935265836,"Address":"1b-2,anna nagar,Chennai,India."},
      {"id":5,"Name":"raj","Country code":"+91","Mobile No.":8658685638,"Address":"25,T nagar,Chennai,India."},
      {"id":6,"Name":"maki","Country code":"+91","Mobile No.":92648364523,"Address":"285,poonjolai,rameshwaram,India."},
      {"id":7,"Name":"pavi","Country code":"+91","Mobile No.":759305158648,"Address":"25-5,thirunagar,manamadurai,India."},
      {"id":8,"Name":"dharshini","Country code":"+91","Mobile No.":63232847525,"Address":"246,thevarampur,chettinad,India."},
      {"id":9,"Name":"sudha","Country code":"+91","Mobile No.":70794469486,"Address":"12,Main road,tirupathur,India."},
      {"id":10,"Name":"geetha","Country code":"+91","Mobile No.":9158935438,"Address":"18-5,melur,Madurai,India."}]

# %%
A.insert_many(Data)

# %%
# Make a query to find records you just created.

for i in A.find({}):
  print(i)
# Out:
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e2'), 'id': 0, 'Name': 'saran', 'Country code': '+91', 'Mobile No.': 9159623987, 'Address': '2/129 Vellore,TamilNadu,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e3'), 'id': 1, 'Name': 'sathish', 'Country code': '+91', 'Mobile No.': 74869368593, 'Address': '2-33,tiruattur,TN,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e4'), 'id': 2, 'Name': 'logu', 'Country code': '+91', 'Mobile No.': 8455765655, 'Address': '55-6,anna road,Chennai,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e5'), 'id': 3, 'Name': 'dharuman', 'Country code': '+91', 'Mobile No.': 6495639952, 'Address': '1/85,Anna salai,trichy,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e6'), 'id': 4, 'Name': 'nivetha', 'Country code': '+91', 'Mobile No.': 935265836, 'Address': '1b-2,anna nagar,Chennai,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e7'), 'id': 5, 'Name': 'raj', 'Country code': '+91', 'Mobile No.': 8658685638, 'Address': '25,T nagar,Chennai,India.'}
# ...

# %%
# Modify the records, use the update_one() method. The update_one() method requires two arguments, query and update.

A.update_one({"id":6},{"$set":{"Name":"Ajay"}})

for i in A.find():
   print(i)
# Out:
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e2'), 'id': 0, 'Name': 'saran', 'Country code': '+91', 'Mobile No.': 9159623987, 'Address': '2/129 Vellore,TamilNadu,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e3'), 'id': 1, 'Name': 'sathish', 'Country code': '+91', 'Mobile No.': 74869368593, 'Address': '2-33,tiruattur,TN,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e4'), 'id': 2, 'Name': 'logu', 'Country code': '+91', 'Mobile No.': 8455765655, 'Address': '55-6,anna road,Chennai,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e5'), 'id': 3, 'Name': 'dharuman', 'Country code': '+91', 'Mobile No.': 6495639952, 'Address': '1/85,Anna salai,trichy,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e6'), 'id': 4, 'Name': 'nivetha', 'Country code': '+91', 'Mobile No.': 935265836, 'Address': '1b-2,anna nagar,Chennai,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e7'), 'id': 5, 'Name': 'raj', 'Country code': '+91', 'Mobile No.': 8658685638, 'Address': '25,T nagar,Chennai,India.'}
# ...

# %%
# Delete the record, use delete_one() method. delete_one() requires a query parameter which specifies the document to delete.

A.delete_one({"id":0})

for i in A.find():
   print(i)
# Out:
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e3'), 'id': 1, 'Name': 'sathish', 'Country code': '+91', 'Mobile No.': 74869368593, 'Address': '2-33,tiruattur,TN,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e4'), 'id': 2, 'Name': 'logu', 'Country code': '+91', 'Mobile No.': 8455765655, 'Address': '55-6,anna road,Chennai,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e5'), 'id': 3, 'Name': 'dharuman', 'Country code': '+91', 'Mobile No.': 6495639952, 'Address': '1/85,Anna salai,trichy,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e6'), 'id': 4, 'Name': 'nivetha', 'Country code': '+91', 'Mobile No.': 935265836, 'Address': '1b-2,anna nagar,Chennai,India.'}
# {'_id': ObjectId('6386f0b9baf0f20c792ef1e7'), 'id': 5, 'Name': 'raj', 'Country code': '+91', 'Mobile No.': 8658685638, 'Address': '25,T nagar,Chennai,India.'}
# ...
